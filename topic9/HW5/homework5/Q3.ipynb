# %%
# %matplotlib inline
import matplotlib.pyplot as plt

from sklearn import metrics
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier

import numpy as np
import pandas as pd 

from sklearn.model_selection import train_test_split
import scipy.io as spio

pd.set_option('mode.chained_assignment', None)

# %%
data = pd.read_csv("q3.csv", header=None) 
data.head()
print(data.shape)

X = data[data.columns[:-1]]
y = data[data.columns[54:55]]
X
y
print(y.shape)
print(X.shape)
# Out:
# (170, 55)
# (170, 1)
# (170, 54)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
# fit a logistic regression model to the data
model = LogisticRegression()
model.fit(X_train, y_train)
print(model)
# make predictions
expected = y_test
predicted = model.predict(X_test)
# summarize the fit of the model
print(metrics.classification_report(expected, predicted))
print(metrics.confusion_matrix(expected, predicted))

# make predictions
expected = y
predicted = model.predict(X)
# summarize the fit of the model
print(metrics.classification_report(expected, predicted))
print(metrics.confusion_matrix(expected, predicted))
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)
#               precision    recall  f1-score   support
#
#          0.0       0.93      1.00      0.97        14
#          1.0       1.00      0.95      0.97        20
#
#    micro avg       0.97      0.97      0.97        34
#    macro avg       0.97      0.97      0.97        34
# weighted avg       0.97      0.97      0.97        34
#
# [[14  0]
#  [ 1 19]]
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99        86
#          1.0       1.00      0.99      0.99        84
#
#    micro avg       0.99      0.99      0.99       170
#    macro avg       0.99      0.99      0.99       170
# weighted avg       0.99      0.99      0.99       170
#
# [[86  0]
#  [ 1 83]]
# /home/hadi/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/hadi/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# fit a Naive Bayes model to the data
model = GaussianNB()
model.fit(X_train, y_train)
print(model)
# make predictions
expected = y_test
predicted = model.predict(X_test)
# summarize the fit of the model
print(metrics.classification_report(expected, predicted))
print(metrics.confusion_matrix(expected, predicted))

# make predictions
expected = y
predicted = model.predict(X)
# summarize the fit of the model
print(metrics.classification_report(expected, predicted))
print(metrics.confusion_matrix(expected, predicted))
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)
#               precision    recall  f1-score   support
#
#          0.0       0.93      1.00      0.97        14
#          1.0       1.00      0.95      0.97        20
#
#    micro avg       0.97      0.97      0.97        34
#    macro avg       0.97      0.97      0.97        34
# weighted avg       0.97      0.97      0.97        34
#
# [[14  0]
#  [ 1 19]]
#               precision    recall  f1-score   support
#
#          0.0       0.96      1.00      0.98        86
#          1.0       1.00      0.95      0.98        84
#
#    micro avg       0.98      0.98      0.98       170
#    macro avg       0.98      0.98      0.98       170
# weighted avg       0.98      0.98      0.98       170
#
# [[86  0]
#  [ 4 80]]
# /home/hadi/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# fit a k-nearest neighbor model to the data
model = KNeighborsClassifier()
model.fit(X_train, y_train)
print(model)
# make predictions
expected = y_test
predicted = model.predict(X_test)
# summarize the fit of the model
print(metrics.classification_report(expected, predicted))
print(metrics.confusion_matrix(expected, predicted))

# make predictions
expected = y
predicted = model.predict(X)
# summarize the fit of the model
print(metrics.classification_report(expected, predicted))
print(metrics.confusion_matrix(expected, predicted))
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')
#               precision    recall  f1-score   support
#
#          0.0       0.93      1.00      0.97        14
#          1.0       1.00      0.95      0.97        20
#
#    micro avg       0.97      0.97      0.97        34
#    macro avg       0.97      0.97      0.97        34
# weighted avg       0.97      0.97      0.97        34
#
# [[14  0]
#  [ 1 19]]
#               precision    recall  f1-score   support
#
#          0.0       0.96      1.00      0.98        86
#          1.0       1.00      0.95      0.98        84
#
#    micro avg       0.98      0.98      0.98       170
#    macro avg       0.98      0.98      0.98       170
# weighted avg       0.98      0.98      0.98       170
#
# [[86  0]
#  [ 4 80]]
# /home/hadi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
X2 = data[data.columns[0:2]]
X2
y
print(y.shape)
print(X2.shape)
# Out:
# (170, 1)
# (170, 2)

# %%
X_train, X_test, y_train, y_test = train_test_split(X2, y, test_size=0.20, random_state=42)

# %%
# fit a logistic regression model to the data
model = LogisticRegression()
model.fit(X_train, y_train)
print(model)
# make predictions
expected = y_test
predicted = model.predict(X_test)
# summarize the fit of the model
print(metrics.classification_report(expected, predicted))
print(metrics.confusion_matrix(expected, predicted))

# make predictions
expected = y
predicted = model.predict(X2)
# summarize the fit of the model
print(metrics.classification_report(expected, predicted))
print(metrics.confusion_matrix(expected, predicted))
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.86      0.89        14
#          1.0       0.90      0.95      0.93        20
#
#    micro avg       0.91      0.91      0.91        34
#    macro avg       0.91      0.90      0.91        34
# weighted avg       0.91      0.91      0.91        34
#
# [[12  2]
#  [ 1 19]]
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.90      0.91        86
#          1.0       0.90      0.92      0.91        84
#
#    micro avg       0.91      0.91      0.91       170
#    macro avg       0.91      0.91      0.91       170
# weighted avg       0.91      0.91      0.91       170
#
# [[77  9]
#  [ 7 77]]
# /home/hadi/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/hadi/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# Plot the decision boundary. For that, we will assign a color to each
# point in the mesh [x_min, x_max]x[y_min, y_max].
x_min, x_max = X[0].min() - .5, X[0].max() + .5
y_min, y_max = X[1].min() - .5, X[1].max() + .5
h = .02  # step size in the mesh
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = model.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.figure(1, figsize=(10, 8))
plt.suptitle('Logistic Regression Classification', fontsize=30)
plt.pcolormesh(xx, yy, Z, cmap=plt.cm.Paired)

# Plot also the training points
plt.scatter(X[0], X[1], c=predicted, edgecolors='k', cmap='viridis')
plt.xlabel('X1', fontsize=20)
plt.ylabel('X2', fontsize=20)
# Out:
# Text(0, 0.5, 'X2')

# %%
# fit a Naive Bayes model to the data
model = GaussianNB()
model.fit(X_train, y_train)
print(model)
# make predictions
expected = y_test
predicted = model.predict(X_test)
# summarize the fit of the model
print(metrics.classification_report(expected, predicted))
print(metrics.confusion_matrix(expected, predicted))

# make predictions
expected = y
predicted = model.predict(X2)
# summarize the fit of the model
print(metrics.classification_report(expected, predicted))
print(metrics.confusion_matrix(expected, predicted))
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.86      0.89        14
#          1.0       0.90      0.95      0.93        20
#
#    micro avg       0.91      0.91      0.91        34
#    macro avg       0.91      0.90      0.91        34
# weighted avg       0.91      0.91      0.91        34
#
# [[12  2]
#  [ 1 19]]
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.92      0.91        86
#          1.0       0.92      0.90      0.91        84
#
#    micro avg       0.91      0.91      0.91       170
#    macro avg       0.91      0.91      0.91       170
# weighted avg       0.91      0.91      0.91       170
#
# [[79  7]
#  [ 8 76]]
# /home/hadi/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# Plot the decision boundary. For that, we will assign a color to each
# point in the mesh [x_min, x_max]x[y_min, y_max].
x_min, x_max = X[0].min() - .5, X[0].max() + .5
y_min, y_max = X[1].min() - .5, X[1].max() + .5
h = .02  # step size in the mesh
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = model.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.figure(1, figsize=(10, 8))
plt.suptitle('Gaussian Naive Bayes Classification', fontsize=30)
plt.pcolormesh(xx, yy, Z, cmap=plt.cm.Paired)

# Plot also the training points
plt.scatter(X[0], X[1], c=predicted, edgecolors='k', cmap='viridis')
plt.xlabel('X1', fontsize=20)
plt.ylabel('X2', fontsize=20)
# Out:
# Text(0, 0.5, 'X2')

# %%
# fit a k-nearest neighbor model to the data
model = KNeighborsClassifier()
model.fit(X_train, y_train)
print(model)
# make predictions
expected = y_test
predicted = model.predict(X_test)
# summarize the fit of the model
print(metrics.classification_report(expected, predicted))
print(metrics.confusion_matrix(expected, predicted))

# make predictions
expected = y
predicted = model.predict(X2)
# summarize the fit of the model
print(metrics.classification_report(expected, predicted))
print(metrics.confusion_matrix(expected, predicted))
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.86      0.89        14
#          1.0       0.90      0.95      0.93        20
#
#    micro avg       0.91      0.91      0.91        34
#    macro avg       0.91      0.90      0.91        34
# weighted avg       0.91      0.91      0.91        34
#
# [[12  2]
#  [ 1 19]]
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.90      0.91        86
#          1.0       0.90      0.93      0.91        84
#
#    micro avg       0.91      0.91      0.91       170
#    macro avg       0.91      0.91      0.91       170
# weighted avg       0.91      0.91      0.91       170
#
# [[77  9]
#  [ 6 78]]
# /home/hadi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Plot the decision boundary. For that, we will assign a color to each
# point in the mesh [x_min, x_max]x[y_min, y_max].
x_min, x_max = X[0].min() - .5, X[0].max() + .5
y_min, y_max = X[1].min() - .5, X[1].max() + .5
h = .02  # step size in the mesh
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = model.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.figure(1, figsize=(10, 8))
plt.suptitle('KNN Classification', fontsize=30)
plt.pcolormesh(xx, yy, Z, cmap=plt.cm.Paired)

# Plot also the training points
plt.scatter(X[0], X[1], c=predicted, edgecolors='k', cmap='viridis')
plt.xlabel('X1', fontsize=20)
plt.ylabel('X2', fontsize=20)
# Out:
# Text(0, 0.5, 'X2')

# %% [markdown]
# # Q3 - b

# %%
# Read the data file. We will transpose it to have all data in rows instead of in columns.
# each row is a 28X28 pixel digit for one mnist data

X = spio.loadmat('data.mat',squeeze_me=True)['data']
print(X.shape)
print(type(X))
X = X.T
print(X.shape)
print(type(X))
# Out:
# (784, 1990)
# <class 'numpy.ndarray'>
# (1990, 784)
# <class 'numpy.ndarray'>

# %%
# We read the labels. 
# We will use this labels to measure the precision of our algorithm
# We categorize digit two as 0 and digit six as category 1
# this is technically for part (c)

y = spio.loadmat('label.mat', squeeze_me=True)['trueLabel']
print(y.shape)
print(y)
y[y==2] = 0
print(y)
y[y==6] = 1
print(y)
# Out:
# (1990,)
# [2 2 2 ... 6 6 6]
# [0 0 0 ... 6 6 6]
# [0 0 0 ... 1 1 1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
# fit a logistic regression model to the data
model = LogisticRegression()
model.fit(X_train, y_train)
print(model)
# make predictions
expected = y_test
predicted = model.predict(X_test)
# summarize the fit of the model
print(metrics.classification_report(expected, predicted))
print(metrics.confusion_matrix(expected, predicted))

# make predictions
expected = y
predicted = model.predict(X)
# summarize the fit of the model
print(metrics.classification_report(expected, predicted))
print(metrics.confusion_matrix(expected, predicted))
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       201
#            1       0.98      0.98      0.98       197
#
#    micro avg       0.98      0.98      0.98       398
#    macro avg       0.98      0.98      0.98       398
# weighted avg       0.98      0.98      0.98       398
#
# [[197   4]
#  [  3 194]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      1032
#            1       0.99      1.00      1.00       958
#
#    micro avg       1.00      1.00      1.00      1990
#    macro avg       1.00      1.00      1.00      1990
# weighted avg       1.00      1.00      1.00      1990
#
# [[1026    6]
#  [   3  955]]
# /home/hadi/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
# fit a Naive Bayes model to the data
model = GaussianNB()
model.fit(X_train, y_train)
print(model)
# make predictions
expected = y_test
predicted = model.predict(X_test)
# summarize the fit of the model
print(metrics.classification_report(expected, predicted))
print(metrics.confusion_matrix(expected, predicted))

# make predictions
expected = y
predicted = model.predict(X)
# summarize the fit of the model
print(metrics.classification_report(expected, predicted))
print(metrics.confusion_matrix(expected, predicted))
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)
#               precision    recall  f1-score   support
#
#            0       0.98      0.63      0.77       201
#            1       0.72      0.99      0.84       197
#
#    micro avg       0.81      0.81      0.81       398
#    macro avg       0.85      0.81      0.80       398
# weighted avg       0.85      0.81      0.80       398
#
# [[126  75]
#  [  2 195]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.61      0.75      1032
#            1       0.70      0.99      0.82       958
#
#    micro avg       0.79      0.79      0.79      1990
#    macro avg       0.85      0.80      0.79      1990
# weighted avg       0.85      0.79      0.79      1990
#
# [[628 404]
#  [  7 951]]

# %%
# fit a k-nearest neighbor model to the data
model = KNeighborsClassifier()
model.fit(X_train, y_train)
print(model)
# make predictions
expected = y_test
predicted = model.predict(X_test)
# summarize the fit of the model
print(metrics.classification_report(expected, predicted))
print(metrics.confusion_matrix(expected, predicted))

# make predictions
expected = y
predicted = model.predict(X)
# summarize the fit of the model
print(metrics.classification_report(expected, predicted))
print(metrics.confusion_matrix(expected, predicted))
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       201
#            1       0.99      1.00      1.00       197
#
#    micro avg       1.00      1.00      1.00       398
#    macro avg       1.00      1.00      1.00       398
# weighted avg       1.00      1.00      1.00       398
#
# [[200   1]
#  [  0 197]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      1032
#            1       0.99      1.00      1.00       958
#
#    micro avg       1.00      1.00      1.00      1990
#    macro avg       1.00      1.00      1.00      1990
# weighted avg       1.00      1.00      1.00      1990
#
# [[1026    6]
#  [   1  957]]

# %%
# we will use PCA to pick the first two component of the data
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit(X)
X2 =  pca.transform(X)

X_train, X_test, y_train, y_test = train_test_split(X2, y, test_size=0.20, random_state=42)

# %%
# fit a logistic regression model to the data
model = LogisticRegression()
model.fit(X_train, y_train)
print(model)
# make predictions
expected = y_test
predicted = model.predict(X_test)
# summarize the fit of the model
print(metrics.classification_report(expected, predicted))
print(metrics.confusion_matrix(expected, predicted))

# make predictions
expected = y
predicted = model.predict(X2)
# summarize the fit of the model
print(metrics.classification_report(expected, predicted))
print(metrics.confusion_matrix(expected, predicted))
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94       201
#            1       0.93      0.94      0.94       197
#
#    micro avg       0.94      0.94      0.94       398
#    macro avg       0.94      0.94      0.94       398
# weighted avg       0.94      0.94      0.94       398
#
# [[188  13]
#  [ 12 185]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94      1032
#            1       0.93      0.94      0.94       958
#
#    micro avg       0.94      0.94      0.94      1990
#    macro avg       0.94      0.94      0.94      1990
# weighted avg       0.94      0.94      0.94      1990
#
# [[969  63]
#  [ 57 901]]
# /home/hadi/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
# Plot the decision boundary. For that, we will assign a color to each
# point in the mesh [x_min, x_max]x[y_min, y_max].
x_min, x_max = X2[:, 0].min() - .5, X2[:, 0].max() + .5
y_min, y_max = X2[:, 1].min() - .5, X2[:, 1].max() + .5
h = .02  # step size in the mesh
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = model.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.figure(1, figsize=(10, 8))
plt.suptitle('Logistic Regression Classification', fontsize=30)
plt.pcolormesh(xx, yy, Z, cmap=plt.cm.Paired)

# Plot also the training points
plt.scatter(X2[:, 0], X2[:, 1], c=predicted,  edgecolors='k', cmap='viridis')
plt.xlabel('X1', fontsize=20)
plt.ylabel('X2', fontsize=20)
# Out:
# Text(0, 0.5, 'X2')

# %%
# fit a Naive Bayes model to the data
model = GaussianNB()
model.fit(X_train, y_train)
print(model)
# make predictions
expected = y_test
predicted = model.predict(X_test)
# summarize the fit of the model
print(metrics.classification_report(expected, predicted))
print(metrics.confusion_matrix(expected, predicted))

# make predictions
expected = y
predicted = model.predict(X2)
# summarize the fit of the model
print(metrics.classification_report(expected, predicted))
print(metrics.confusion_matrix(expected, predicted))
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)
#               precision    recall  f1-score   support
#
#            0       0.92      0.95      0.93       201
#            1       0.94      0.91      0.93       197
#
#    micro avg       0.93      0.93      0.93       398
#    macro avg       0.93      0.93      0.93       398
# weighted avg       0.93      0.93      0.93       398
#
# [[190  11]
#  [ 17 180]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93      1032
#            1       0.93      0.91      0.92       958
#
#    micro avg       0.93      0.93      0.93      1990
#    macro avg       0.93      0.93      0.93      1990
# weighted avg       0.93      0.93      0.93      1990
#
# [[966  66]
#  [ 82 876]]

# %%
# Plot the decision boundary. For that, we will assign a color to each
# point in the mesh [x_min, x_max]x[y_min, y_max].
x_min, x_max = X2[:, 0].min() - .5, X2[:, 0].max() + .5
y_min, y_max = X2[:, 1].min() - .5, X2[:, 1].max() + .5
h = .02  # step size in the mesh
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = model.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.figure(1, figsize=(10, 8))
plt.suptitle('Gaussian Naive Bayes Classification', fontsize=30)
plt.pcolormesh(xx, yy, Z, cmap=plt.cm.Paired)

# Plot also the training points
plt.scatter(X2[:, 0], X2[:, 1], c=predicted,  edgecolors='k', cmap='viridis')
plt.xlabel('X1', fontsize=20)
plt.ylabel('X2', fontsize=20)
# Out:
# Text(0, 0.5, 'X2')

# %%
# fit a k-nearest neighbor model to the data
model = KNeighborsClassifier()
model.fit(X_train, y_train)
print(model)
# make predictions
expected = y_test
predicted = model.predict(X_test)
# summarize the fit of the model
print(metrics.classification_report(expected, predicted))
print(metrics.confusion_matrix(expected, predicted))

# make predictions
expected = y
predicted = model.predict(X2)
# summarize the fit of the model
print(metrics.classification_report(expected, predicted))
print(metrics.confusion_matrix(expected, predicted))
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')
#               precision    recall  f1-score   support
#
#            0       0.94      0.93      0.93       201
#            1       0.93      0.94      0.93       197
#
#    micro avg       0.93      0.93      0.93       398
#    macro avg       0.93      0.93      0.93       398
# weighted avg       0.93      0.93      0.93       398
#
# [[186  15]
#  [ 11 186]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95      1032
#            1       0.93      0.96      0.95       958
#
#    micro avg       0.95      0.95      0.95      1990
#    macro avg       0.95      0.95      0.95      1990
# weighted avg       0.95      0.95      0.95      1990
#
# [[967  65]
#  [ 40 918]]

# %%
# Plot the decision boundary. For that, we will assign a color to each
# point in the mesh [x_min, x_max]x[y_min, y_max].
x_min, x_max = X2[:, 0].min() - .5, X2[:, 0].max() + .5
y_min, y_max = X2[:, 1].min() - .5, X2[:, 1].max() + .5
h = .02  # step size in the mesh
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = model.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.figure(1, figsize=(10, 8))
plt.suptitle('KNN Classification', fontsize=30)
plt.pcolormesh(xx, yy, Z, cmap=plt.cm.Paired)

# Plot also the training points
plt.scatter(X2[:, 0], X2[:, 1], c=predicted,  edgecolors='k', cmap='viridis')
plt.xlabel('X1', fontsize=20)
plt.ylabel('X2', fontsize=20)
# Out:
# Text(0, 0.5, 'X2')
